# %% [markdown]
# # Введение в обработку текста на естественном языке

# %% [markdown]
# Материалы:
# * Макрушин С.В. Лекция 9: Введение в обработку текста на естественном языке\
# * https://realpython.com/nltk-nlp-python/
# * https://scikit-learn.org/stable/modules/feature_extraction.html

# %% [markdown]
# ## Задачи для совместного разбора

# %%
from sklearn.feature_extraction.text import CountVectorizer
import pymorphy2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 from sklearn.feature_extraction.text import CountVectorizer
# ----> 2 import pymorphy2
#
# ModuleNotFoundError: No module named 'pymorphy2'

# %% [markdown]
# 1. Считайте слова из файла `litw-win.txt` и запишите их в список `words`. В заданном предложении исправьте все опечатки, заменив слова с опечатками на ближайшие (в смысле расстояния Левенштейна) к ним слова из списка `words`. Считайте, что в слове есть опечатка, если данное слово не содержится в списке `words`.

# %%
text = '''с велечайшим усилием выбравшись из потока убегающих людей Кутузов со свитой уменьшевшейся вдвое поехал на звуки выстрелов русских орудий'''

# %% [markdown]
# 2. Разбейте текст из формулировки задания 1 на слова; проведите стемминг и лемматизацию слов.

# %% [markdown]
# 3. Преобразуйте предложения из формулировки задания 1 в векторы при помощи `CountVectorizer`.

# %% [markdown]
# ## Лабораторная работа 9

# %% [markdown]
# ### Расстояние редактирования

# %% [markdown]
# 1.1 Загрузите предобработанные описания рецептов из файла `preprocessed_descriptions.csv`. Получите набор уникальных слов `words`, содержащихся в текстах описаний рецептов (воспользуйтесь `word_tokenize` из `nltk`).

# %%
import nltk

# Прочитаем данные из файла с правильной кодировкой
with open('litw-win.txt', 'r', encoding='windows-1251') as f:
    lines = f.readlines()

# Объединим строки в один текст
text = ' '.join(line.split()[1] for line in lines if len(line.split()) > 1)

# Токенизируем текст
words = nltk.word_tokenize(text)

# Получим уникальные слова  
unique_words = set(words)

# Выведем количество уникальных слов и сами слова
unique_words
# Out:
# {'раскосившиеся',
#  'препя',
#  'окруженному',
#  'векторе',
#  'поблагословить',
#  'обрадовала',
#  'чашечки',
#  'пугнет',
#  'подошл',
#  'разломил',
#  'шуметь',
#  'маже',
#  'франц',
#  'проскандировал',
#  'цветки',
#  'каторги',
#  'тростника',
#  'затаит',
#  'стаканчик',
#  'запрестольный',
#  'прядях',
#  'земля',
#  'воспели',
#  'думае',
#  'залаяла',
#  'примиряющий',
#  'провинциальным',
#  'демытрович',
#  'порочных',
#  'клеветать',
#  'неудобно',
#  'кипели',
#  'сирень',
#  'аверкии',
#  'свидригайлове',
#  'погулять',
#  'съел',
#  'памятны',
#  'кривляются',
#  'уклоненной',
#  'подносом',
#  'познаниям',
#  'сук',
#  'зальет',
#  'студодейное',
#  'бисаврюк',
#  'сквозила',
#  'чертовская',
#  'неуловим',
#  'косвенных',
#  'воо',
#  'чудосия',
#  'предприимчивому',
#  'отскочи',
#  'злобою',
#  'изловчавшегося',
#  'впускай',
#  'сокращения',
#  'разгинаясь',
#  'романтические',
#  'степановы',
#  'вырастала',
#  'лихорадочный',
#  'опустошали',
#  'потупляли',
#  'гложет',
#  'смягчилась',
#  'всеобщее',
#  'псу',
#  'воскре',
#  'седоватою',
#  'одея',
#  'огородник',
#  'словил',
#  'соображаю',
#  'помещенном',
#  'фалангу',
#  'обличаться',
#  'составлена',
#  'переда',
#  'зазвеневшие',
#  'заступления',
#  'еврейские',
#  'укомплект',
#  'неразрешающегося',
#  'кривого',
#  'сломалось',
#  'пасси',
#  'крепилась',
#  'крота',
#  'промежуток',
#  'расстройстве',
#  'известнейшим',
#  'уцелел',
#  'плотоядие',
#  'утерпев',
#  'простит',
#  'побежать',
#  'допили',
#  'ловкость',
#  'топорны',
#  'увлекаюсь',
#  'игнат',
#  'протяжении',
#  'шубой',
#  'дворишко',
#  'изгол',
#  'баталионов',
#  'установ',
#  'снимали',
#  'вытерплю',
#  'засмеетесь',
#  'медовы',
#  'вылезут',
#  'связанные',
#  'отдельною',
#  'вилял',
#  'усматривал',
#  'просвещенных',
#  'возлюбленного',
#  'жилетом',
#  'заденет',
#  'растерзанной',
#  'термометрическому',
#  'беленький',
#  'повышающимся',
#  'стеклянною',
#  'жизнерадостной',
#  'двуперстным',
#  'увлекается',
#  'натешьс',
#  'вероятны',
#  'неминуемую',
#  'обдерет',
#  'запасы',
#  'бывай',
#  'средне',
#  'отзывается',
#  'тщесла',
#  'прячущихся',
#  'скучась',
#  'перерезывали',
#  'меду',
#  'лишениями',
#  'прихлопну',
#  'подсуд',
#  'сохранявшегося',
#  'попомнили',
#  'исступле',
#  'кастальским',
#  'избранников',
#  'испробовали',
#  'напил',
#  'закала',
#  'улыбающемуся',
#  'богоотступник',
#  'стерла',
#  'такового',
#  'смешнейших',
#  'лакейства',
#  'полага',
#  'посвятит',
#  'лента',
#  'голосила',
#  'лучезарнейший',
#  'краткое',
#  'уличил',
#  'навесами',
#  'назаперти',
#  'благополучия',
#  'сгруб',
#  'старуху',
#  'авдот',
#  'чрезвыча',
#  'смотря',
#  'хохотать',
#  'атласным',
#  'подар',
#  'отпрыск',
#  'болталась',
#  'праздношатавшегося',
#  'пау',
#  'побеждала',
#  'выдергивались',
#  'оттени',
#  'сношения',
#  'воздушным',
#  'архипелаг',
#  'предчувствовавшая',
#  'генеральшею',
#  'осудить',
#  'фук',
#  'косынка',
#  'афанасьеви',
#  'кроила',
#  'взнузд',
#  'босоногих',
#  'здравствует',
#  'кузьмичу',
#  'грабеж',
#  'сцепился',
#  'бранятся',
#  'помож',
#  'протанцев',
#  'угрева',
#  'уладились',
#  'выражает',
#  'непочтительно',
#  'отпо',
#  'почерневшей',
#  'записывает',
#  'проделать',
#  'изобретет',
#  'сорву',
#  'проблеял',
#  'логиныч',
#  'раздражительная',
#  'заплели',
#  'разбросанных',
#  'рундуком',
#  'реноме',
#  'выпытывала',
#  'поставишь',
#  'ревнивец',
#  'схопилась',
#  'ввязываюсь',
#  'доискался',
#  'подвитая',
#  'личностев',
#  'сладили',
#  'локотком',
#  'задвинул',
#  'дават',
#  'некрасивого',
#  'венгерский',
#  'пользуюсь',
#  'лизаветы',
#  'кисловатой',
#  'извлекший',
#  'усеян',
#  'молитва',
#  'умиление',
#  'простыми',
#  'убеждала',
#  'помещ',
#  'воскликнут',
#  'сухенькая',
#  'рабское',
#  'безгласна',
#  'ломался',
#  'устраивать',
#  'поднятой',
#  'развязал',
#  'натерпелась',
#  'прованса',
#  'доищусь',
#  'джентльменской',
#  'перенес',
#  'циркуляров',
#  'трехмачтовый',
#  'сладкую',
#  'убытке',
#  'сказывались',
#  'вспыхнет',
#  'треснешь',
#  'помешат',
#  'бере',
#  'попадать',
#  'внятием',
#  'потушен',
#  'дозволенными',
#  'каватины',
#  'как',
#  'воцарялась',
#  'окошка',
#  'зашедшая',
#  'огорчившись',
#  'отпускалось',
#  'помощнице',
#  'заложенный',
#  'чекань',
#  'увядающей',
#  'безрассудное',
#  'заменятся',
#  'кунью',
#  'виноградными',
#  'закусывает',
#  'ключицей',
#  'десных',
#  'жаловали',
#  'стремена',
#  'испрашивать',
#  'караванам',
#  'мужчинище',
#  'натураль',
#  'надлежащий',
#  'содрогнется',
#  'беседке',
#  'двинула',
#  'господню',
#  'разыграло',
#  'ймыт',
#  'постоян',
#  'атакует',
#  'шабашевичам',
#  'разговорить',
#  'штиблетами',
#  'щекотало',
#  'столоначальнику',
#  'медвежьим',
#  'рыцар',
#  'лесных',
#  'тяжелее',
#  'пошире',
#  'господствование',
#  'чистенький',
#  'дробяжкин',
#  'привести',
#  'нравоученью',
#  'душевному',
#  'хладнокровным',
#  'проиграть',
#  'благотворитель',
#  'гумилевский',
#  'предварительного',
#  'обещаюсь',
#  'открывала',
#  'пиндара',
#  'унижающих',
#  'солжем',
#  'истребится',
#  'пригладился',
#  'разлитой',
#  'пускаясь',
#  'ущипнуло',
#  'вычет',
#  'целомудренностью',
#  'тяпн',
#  'явными',
#  'приготовлялись',
#  'бригадного',
#  'пьешь',
#  'китайской',
#  'горчишник',
#  'несу',
#  'доступно',
#  'прохарчина',
#  'причесанным',
#  'утрешь',
#  'отдаленной',
#  'осквернил',
#  'рваным',
#  'помолчите',
#  'бил',
#  'пролитую',
#  'вышину',
#  'причинна',
#  'игрив',
#  'дурни',
#  'бледневший',
#  'опровержения',
#  'безв',
#  'пенсиончики',
#  'петрович',
#  'искриви',
#  'дж',
#  'воюющие',
#  'отверне',
#  'пинетти',
#  'захарушку',
#  'березах',
#  'приманку',
#  'сливных',
#  'заскорузлые',
#  'завлеч',
#  'четвертак',
#  'раскуривает',
#  'колебанья',
#  'кокетство',
#  'прописана',
#  'опаздывай',
#  'выпяти',
#  'колбасников',
#  'талеры',
#  'растратил',
#  'умничает',
#  'травах',
#  'почитался',
#  'завязли',
#  'канцеляристы',
#  'безбожным',
#  'укусов',
#  'серь',
#  'складов',
#  'отрицательно',
#  'усталостью',
#  'вдумчивою',
#  'поломойная',
#  'закоптевшей',
#  'случался',
#  'добру',
#  'пораспек',
#  'величайшею',
#  'тираном',
#  'публичные',
#  'утомлена',
#  'оракула',
#  'скакал',
#  'пись',
#  'отдален',
#  'почку',
#  'згад',
#  'сысоевна',
#  'руси',
#  'достославного',
#  'обесславленное',
#  'разбился',
#  'суетным',
#  'угадайте',
#  'нефедушка',
#  'наделены',
#  'заречья',
#  'барских',
#  'раззадорить',
#  'ружьев',
#  'недоверчивого',
#  'фамильишки',
#  'собственному',
#  'присяжные',
#  'школьничество',
#  'усадив',
#  'развратный',
#  'пересиливали',
#  'тесто',
#  'чиркнул',
#  'опустелое',
#  'потружусь',
#  'кипарисному',
#  'обнаруживалас',
#  'единс',
#  'предали',
#  'негоже',
#  'швейцарию',
#  'совершена',
#  'ловушках',
#  'пошутить',
#  'захотела',
#  'разрыве',
#  'охладела',
#  'акация',
#  'низводите',
#  'усложнялось',
#  'покопавшись',
#  'представителях',
#  'мечети',
#  'цените',
#  'калаушин',
#  'законна',
#  'городовому',
#  'начне',
#  'вскрытии',
#  'нападем',
#  'пришел',
#  'ползать',
#  'рассеяно',
#  'мыльные',
#  'разлучае',
#  'антитезом',
#  'пташек',
#  'полусумасшедшее',
#  'уклоняя',
#  'позднейшие',
#  'блистающая',
#  'переехал',
#  'бережете',
#  'поучений',
#  'владельцу',
#  'приносимой',
#  'связно',
#  'олеандра',
#  'крестит',
#  'надавил',
#  'недалекий',
#  'легч',
#  'веселюсь',
#  'малютине',
#  'осторожная',
#  'отрицан',
#  'верителям',
#  'изменять',
#  'своре',
#  'прик',
#  'поражала',
#  'разорились',
#  'вскинул',
#  'ужаснее',
#  'семик',
#  'успе',
#  'дне',
#  'бессвязное',
#  'неприятель',
#  'повалились',
#  'мыслию',
#  'егорова',
#  'женщинах',
#  'догорел',
#  'вокру',
#  'рвалась',
#  'подчас',
#  'начертана',
#  'бесчиновной',
#  'благоденствуют',
#  'охая',
#  'умиравшим',
#  'неженатый',
#  'шедшем',
#  'поверю',
#  'незнакомыми',
#  'подым',
#  'страстными',
#  'ополчение',
#  'процветающую',
#  'таемый',
#  'крести',
#  'всползает',
#  'почел',
#  'пожелтевшую',
#  'петербургскую',
#  'манкированный',
#  'завизжала',
#  'седым',
#  'критикует',
#  'услужливостью',
#  'букашка',
#  'сотворяя',
#  'парфенович',
#  'патрид',
#  'молятся',
#  'домашнею',
#  'занести',
#  'брички',
#  'неспокойство',
#  'канва',
#  'целков',
#  'круче',
#  'анекдотцем',
#  'форменный',
#  'матвеевич',
#  'освобож',
#  'единичны',
#  'чащ',
#  'лощино',
#  'долгу',
#  'завистлив',
#  'вспухшими',
#  'посмотр',
#  'изобразившегося',
#  'квартируете',
#  'изучены',
#  'предвзятая',
#  'одной',
#  'пересе',
#  'спирало',
#  'пирамиде',
#  'сувенира',
#  'обледеневала',
#  'буграми',
#  'выним',
#  'соотношениях',
#  'естественна',
#  'скрывались',
#  'сотенка',
#  'обессудьте',
#  'подгородном',
#  'воротничками',
#  'срамные',
#  'торчмя',
#  'сменил',
#  'дильеру',
#  'францюзы',
#  'сбережет',
#  'утешен',
#  'заутрени',
#  'потолкуем',
#  'порадовался',
#  'неблагонадежное',
#  'бородатой',
#  'залито',
#  'сновавшей',
#  'жечь',
#  'почувствована',
#  'назар',
#  'проспит',
#  'спрятана',
#  'просвечивал',
#  'крушиться',
#  'перевязкам',
#  'куполе',
#  'светлицына',
#  'односпальная',
#  'уловом',
#  'потребу',
#  'прису',
#  'сплетник',
#  'смягченные',
#  'вышку',
#  'ловят',
#  'часок',
#  'припомнился',
#  'кирпичом',
#  'предпочитается',
#  'изумруд',
#  'презирать',
#  'разорвали',
#  'побежденные',
#  'приковались',
#  'съезжалось',
#  'стуса',
#  'ссыпано',
#  'забору',
#  'комбинации',
#  'микроскопом',
#  'варево',
#  'козацкие',
#  'гамана',
#  'кофейщику',
#  'грустившего',
#  'стать',
#  'ляховым',
#  'проносились',
#  'умело',
#  'патронессой',
#  'шалуны',
#  'напрашиваетесь',
#  'малеванием',
#  'сохнущими',
#  'прячутся',
#  'горева',
#  'комнатку',
#  'породить',
#  'иголочкой',
#  'губам',
#  'толкутся',
#  'инстинктивной',
#  'отрывок',
#  'снисходительный',
#  'дубовое',
#  'неутомим',
#  'адописная',
#  'ненави',
#  'мисхором',
#  'залив',
#  'поступи',
#  'сандал',
#  'разоделась',
#  'карповна',
#  'лорнетку',
#  'беззаботности',
#  'новооткрытой',
#  'утесы',
#  'титании',
#  'шубку',
#  'призадумалась',
#  'насек',
#  'саратовскую',
#  'стены',
#  'засовывать',
#  'берего',
#  'вычурно',
#  'перебита',
#  'ветерок',
#  'обыкновенное',
#  'вспоминаешь',
#  'опускаяс',
#  'выпячиваются',
#  'майором',
#  'столковались',
#  'прохо',
#  'благонамеренна',
#  'семьд',
#  'гранах',
#  'поймем',
#  'побегать',
#  'булавки',
#  'сокрытых',
#  'шестую',
#  'расторг',
#  'возрос',
#  'вирт',
#  'привя',
#  'летоп',
#  'бременю',
#  'господним',
#  'посыпать',
#  'свойственный',
#  'стукнем',
#  'произнесут',
#  'кружевами',
#  'молений',
#  'примадоннах',
#  'звания',
#  'применивался',
#  'кипел',
#  'пианисты',
#  'утес',
#  'федерати',
#  'материалами',
#  'сохранялись',
#  'зажгла',
#  'угождения',
#  'водоемом',
#  'дослушаете',
#  'незаслуженным',
#  'твердою',
#  'мурин',
#  'полесовщику',
#  'гривну',
#  'накипевшая',
#  'свечей',
#  'жеребца',
#  'принудительную',
#  'приве',
#  'спершие',
#  'кодекс',
#  'пристальный',
#  'полотняных',
#  'излияниями',
#  'подпольною',
#  'втягива',
#  'сатанинское',
#  'мишина',
#  'левей',
#  'ободренный',
#  'прельщая',
#  'укладываньем',
#  'изяществе',
#  'омерзительно',
#  'купив',
#  'прыгал',
#  'глиняную',
#  'мечтанную',
#  'отверстые',
#  'раскрасн',
#  'раздавил',
#  'перепутанные',
#  'протанц',
#  'ложечкой',
#  'рубины',
#  'обивкой',
#  'понев',
#  'ловеласом',
#  'картинки',
#  'угасшая',
#  'неосторожна',
#  'всадника',
#  'остричь',
#  'плешивых',
#  'осьмнадцатидушным',
#  'приставлены',
#  'отнимал',
#  'надзор',
#  'баронесса',
#  'оголенною',
#  'мошенничество',
#  'зрачках',
#  'пригл',
#  'ярлычок',
#  'испытавший',
#  'проняло',
#  'удивившая',
#  'переполненный',
#  'кука',
#  'сентиментальничанье',
#  'мотыкою',
#  'библиот',
#  'пише',
#  'убран',
#  'духовщине',
#  'томилась',
#  'рожок',
#  'вертеться',
#  'манной',
#  'набился',
#  'уезжавшему',
#  'дево',
#  'шевельнуться',
#  'разному',
#  'ненастоящими',
#  'забирали',
#  'принялис',
#  'уничтожающий',
#  'назанского',
#  'сочту',
#  'наденьте',
#  'сварливая',
#  'стальное',
#  'полуфрака',
#  'нагнувшейся',
#  'запрещение',
#  'выгодна',
#  'трои',
#  'смешливая',
#  'храп',
#  'поси',
#  'жму',
#  'сведений',
#  'орденску',
#  'подпадет',
#  'непорушно',
#  'капитальном',
#  'залег',
#  'покойный',
#  'столетием',
#  'ободрившийся',
#  'пропела',
#  'сбережениями',
#  'равновесию',
#  'шейхов',
#  'марсель',
#  'омерзительным',
#  'нижних',
#  'царапнула',
#  'рисунки',
#  'аг',
#  'обольщена',
#  'напротив',
#  'лицем',
#  'спаленка',
#  'упрекающий',
#  'проведают',
#  'изгиб',
#  'глотк',
#  'жгун',
#  'одуряющей',
#  'ферапонт',
#  'услащенно',
#  'действенность',
#  'ухмыляешься',
#  'клапанов',
#  'придумаешь',
#  'неудовольствий',
#  'карьерах',
#  'фа',
#  'сухопутный',
#  'суммам',
#  'выслушавшей',
#  'тщание',
#  'платовым',
#  'восстала',
#  'заменился',
#  'широкоплечая',
#  'мотивов',
#  'возникавшем',
#  'армейской',
#  'приучаюсь',
#  'избавлю',
#  'затряслись',
#  'проломил',
#  'бабкина',
#  'называемого',
#  'холе',
#  'шематон',
#  'мишуры',
#  'займите',
#  'отшат',
#  'жилистой',
#  'трущобные',
#  'подачки',
#  'хищным',
#  'кофейников',
#  'отозвалась',
#  'страни',
#  'обмеривают',
#  'сероухих',
#  'выстрелят',
#  'горкой',
#  'красноречие',
#  'произносят',
#  'завязала',
#  'спожинки',
#  'рявканье',
#  'уцелевший',
#  'абонируюсь',
#  'изучался',
#  'печатания',
#  'возгл',
#  'штопал',
#  'выкаченным',
#  'общая',
#  'подсудимому',
#  'завязывала',
#  'сви',
#  'конт',
#  'поют',
#  'яхте',
#  'тревожный',
#  'бряканье',
#  'вознесенный',
#  'чувствительность',
#  'придуманное',
#  'хлысне',
#  'противоречи',
#  'чрезвычайную',
#  'растянувшуюся',
#  'горькому',
#  'ткача',
#  'тревожн',
#  'лампочки',
#  'испугана',
#  'повестей',
#  'арестантик',
#  'допрашивает',
#  'череви',
#  'подвязать',
#  'фигуранты',
#  'убранной',
#  'сбегая',
#  'лягавая',
#  'улепетывал',
#  'взбесивший',
#  'вековечных',
#  'сердцеведение',
#  'гайнаном',
#  'подпоясаны',
#  'сн',
#  'мироздание',
#  'сучнища',
#  'вздум',
#  'позвавших',
#  'переписыватьс',
#  'нескольку',
#  'ступеньку',
#  'успокоило',
#  'улучшений',
#  'конная',
#  'расцеловать',
#  'получении',
#  'бакенбардам',
#  'прек',
#  'строганов',
#  'недосиженные',
#  'торговку',
#  'ласкаться',
#  'младенцам',
#  'шкаф',
#  'буквальною',
#  'заводить',
#  'залежалый',
#  'стремительностью',
#  'трепавший',
#  'наброшенные',
#  'клочек',
#  'причислила',
#  'воротный',
#  'насильном',
#  'непривычного',
#  'гешефтом',
#  'привечать',
#  'исследуем',
#  'оное',
#  'успокоивающей',
#  'телодвижений',
#  'павший',
#  'разбирани',
#  'сотам',
#  'грузными',
#  'облога',
#  'индивидуал',
#  'трухачевский',
#  'издевался',
#  'крещен',
#  'субботиной',
#  'томясь',
#  'обливая',
#  'билетом',
#  'навязался',
#  'облегчает',
#  'виляй',
#  'сон',
#  'шкалик',
#  'чуде',
#  'дворцах',
#  'собутыльн',
#  'горлами',
#  'катки',
#  'свежеобитой',
#  'жените',
#  'переписа',
#  'арагва',
#  'открою',
#  'весне',
#  'распаренных',
#  'неоткровенности',
#  'занимавшие',
#  'помогл',
#  'заварного',
#  'отстрижет',
#  'запутавшис',
#  'изобильном',
#  'соломинка',
#  ...}

# %% [markdown]
# 1.2 Сгенерируйте 5 пар случайно выбранных слов и посчитайте между ними расстояние редактирования.

# %%
import random
from nltk.metrics import edit_distance

# Преобразуем уникальные слова в список для случайного выбора
unique_words_list = list(unique_words)

# Генерация 5 случайных пар слов
random_pairs = [(random.choice(unique_words_list), random.choice(unique_words_list)) for _ in range(5)]

# Вычисление расстояния редактирования для каждой пары
for word1, word2 in random_pairs:
    distance = edit_distance(word1, word2)
    print(f'Расстояние редактирования между "{word1}" и "{word2}": {distance}')
# Out:
# Расстояние редактирования между "копии" и "сельских": 7
# Расстояние редактирования между "построенной" и "улепетывайте": 12
# Расстояние редактирования между "библейским" и "вторгнутся": 10
# Расстояние редактирования между "когти" и "вознагражден": 10
# Расстояние редактирования между "лесной" и "заподозренным": 11

# %% [markdown]
# 1.3 Напишите функцию, которая для заданного слова `word` возвращает `k` ближайших к нему слов из списка `words` (близость слов измеряется с помощью расстояния Левенштейна)

# %%
def find_k_nearest_words(word, words, k):
    distances = [(w, edit_distance(word, w)) for w in words]
    # Сортируем по расстоянию и выбираем первые k элементов
    nearest_words = sorted(distances, key=lambda x: x[1])[:k]
    return nearest_words

word = "ратники"
k = 3
nearest_words = find_k_nearest_words(word, unique_words, k)
print(nearest_words)
# Out:
# [('ратники', 0), ('латники', 1), ('ратник', 1)]

# %% [markdown]
# ### Стемминг, лемматизация

# %% [markdown]
# 2.1 На основе результатов 1.1 создайте `pd.DataFrame` со столбцами:
#     * word
#     * stemmed_word
#     * normalized_word
#
# Столбец `word` укажите в качестве индекса.
#
# Для стемминга воспользуйтесь `SnowballStemmer`, для нормализации слов - `WordNetLemmatizer`. Сравните результаты стемминга и лемматизации.

# %%
import pandas as pd
from nltk.stem import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# Инициализируем стеммер и лемматизатор
stemmer = SnowballStemmer('russian')
lemmatizer = WordNetLemmatizer()

# Создаем DataFrame
df = pd.DataFrame(words, columns=['word'])

# Применяем стемминг и лемматизацию
df['stemmed_word'] = df['word'].apply(stemmer.stem)
df['normalized_word'] = df['word'].apply(lemmatizer.lemmatize)

# Указываем 'word' в качестве индекса
df.set_index('word', inplace=True)

# Выводим DataFrame
df
# Out:
#                                                   stemmed_word  \
# word
# и                                                            и
# в                                                            в
# я                                                            я
# с                                                            с
# а                                                            а
# ...                                                        ...
# высокопревосходительства               высокопревосходительств
# попреблагорассмотрительст            попреблагорассмотрительст
# попреблагорассмотрительствующемуся  попреблагорассмотрительств
# убегающих                                                убега
# уменьшившейся                                           уменьш
#
#                                                        normalized_word
# word
# и                                                                    и
# в                                                                    в
# я                                                                    я
# с                                                                    с
# а                                                                    а
# ...                                                                ...
# высокопревосходительства                      высокопревосходительства
# попреблагорассмотрительст                    попреблагорассмотрительст
# попреблагорассмотрительствующемуся  попреблагорассмотрительствующемуся
# убегающих                                                    убегающих
# уменьшившейся                                            уменьшившейся
#
# [162166 rows x 2 columns]

# %% [markdown]
# 2.2. Удалите стоп-слова из описаний рецептов. Какую долю об общего количества слов составляли стоп-слова? Сравните топ-10 самых часто употребляемых слов до и после удаления стоп-слов.

# %%
from nltk.corpus import stopwords
from collections import Counter

# Получаем стоп-слова для русского языка
stop_words = set(stopwords.words('russian'))

# Удаляем стоп-слова
filtered_words = [word for word in words if word.lower() not in stop_words]

# Подсчитываем частоту слов до и после удаления стоп-слов
original_word_counts = Counter(words)
filtered_word_counts = Counter(filtered_words)

# Рассчитываем долю стоп-слов
stop_words_count = len(words) - len(filtered_words)
stop_words_ratio = stop_words_count / len(words)

# Сравниваем топ-10 самых частых слов до и после удаления стоп-слов
top_10_original = original_word_counts.most_common(10)
top_10_filtered = filtered_word_counts.most_common(10)

print(f'Доля стоп-слов: {stop_words_ratio:.2%}')
print('Топ-10 слов до удаления стоп-слов:', top_10_original)
print('Топ-10 слов после удаления стоп-слов:', top_10_filtered)
# Out:
# Доля стоп-слов: 0.09%
# Топ-10 слов до удаления стоп-слов: [('и', 1), ('в', 1), ('я', 1), ('с', 1), ('а', 1), ('к', 1), ('у', 1), ('о', 1), ('н', 1), ('п', 1)]
# Топ-10 слов после удаления стоп-слов: [('н', 1), ('п', 1), ('б', 1), ('т', 1), ('д', 1), ('м', 1), ('ч', 1), ('з', 1), ('г', 1), ('е', 1)]

# %% [markdown]
# ### Векторное представление текста

# %% [markdown]
# 3.1 Выберите случайным образом 5 рецептов из набора данных. Представьте описание каждого рецепта в виде числового вектора при помощи `TfidfVectorizer`

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

df = pd.read_csv('recipes_sample.csv')

# Убедимся, что описания рецептов находятся в колонке 'description'
descriptions = df['description'].dropna().tolist()

# Выбираем случайным образом 5 рецептов
random_indices = random.sample(range(len(descriptions)), 5)
random_descriptions = [descriptions[i] for i in random_indices]
recipe_names = [df.loc[i, 'name'] for i in random_indices]  # Получим названия рецептов

# Инициализируем TfidfVectorizer
vectorizer = TfidfVectorizer()

# Преобразуем тексты в числовые векторы
tfidf_matrix = vectorizer.fit_transform(random_descriptions)

# Преобразуем результат в DataFrame для удобства
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out(), index=recipe_names)

# Выведем результат
tfidf_df
# Out:
#                                                           20     about  \
# chocolate chip cookie delight                       0.000000  0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.130656  0.130656
# cherry walnut breakfast couscous                    0.000000  0.000000
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                     actually    addict  \
# chocolate chip cookie delight                       0.000000  0.304305
# apricot pumpkin bread pudding  diabetic heart h...  0.000000  0.000000
# cherry walnut breakfast couscous                    0.112914  0.000000
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                          and      anna  \
# chocolate chip cookie delight                       0.203796  0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.175004  0.130656
# cherry walnut breakfast couscous                    0.302480  0.000000
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                     anything      beef  \
# chocolate chip cookie delight                       0.000000  0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.000000  0.130656
# cherry walnut breakfast couscous                    0.112914  0.000000
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                     biscuits       bit  ...  \
# chocolate chip cookie delight                       0.000000  0.245511  ...
# apricot pumpkin bread pudding  diabetic heart h...  0.000000  0.000000  ...
# cherry walnut breakfast couscous                    0.112914  0.091099  ...
# corn souffle  stouffer s copycat                    0.000000  0.000000  ...
# basic pasta dough  no egg                           0.000000  0.000000  ...
#
#                                                     unhealthy        up  \
# chocolate chip cookie delight                        0.000000  0.000000
# apricot pumpkin bread pudding  diabetic heart h...   0.000000  0.000000
# cherry walnut breakfast couscous                     0.112914  0.112914
# corn souffle  stouffer s copycat                     0.000000  0.000000
# basic pasta dough  no egg                            0.000000  0.000000
#
#                                                          use       was  \
# chocolate chip cookie delight                       0.000000  0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.391968  0.000000
# cherry walnut breakfast couscous                    0.000000  0.225829
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                           we      when  \
# chocolate chip cookie delight                       0.000000  0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.130656  0.000000
# cherry walnut breakfast couscous                    0.000000  0.112914
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                         will      with  \
# chocolate chip cookie delight                       0.000000  0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.000000  0.000000
# cherry walnut breakfast couscous                    0.112914  0.112914
# corn souffle  stouffer s copycat                    0.000000  0.000000
# basic pasta dough  no egg                           0.000000  0.000000
#
#                                                       woman  worcestershire
# chocolate chip cookie delight                       0.00000        0.000000
# apricot pumpkin bread pudding  diabetic heart h...  0.00000        0.130656
# cherry walnut breakfast couscous                    0.00000        0.000000
# corn souffle  stouffer s copycat                    0.63907        0.000000
# basic pasta dough  no egg                           0.00000        0.000000
#
# [5 rows x 105 columns]

# %% [markdown]
# 3.2 Вычислите близость между каждой парой рецептов, выбранных в задании 3.1, используя косинусное расстояние (`scipy.spatial.distance.cosine`) Результаты оформите в виде таблицы `pd.DataFrame`. В качестве названий строк и столбцов используйте названия рецептов.

# %%
from scipy.spatial.distance import cosine

df = pd.read_csv('recipes_sample.csv')

# Убедимся, что описания рецептов находятся в колонке 'description'
descriptions = df['description'].dropna().tolist()
recipe_names = df['name'].dropna().tolist()  # Получим список названий рецептов

# Выбираем случайным образом 5 рецептов
random_indices = random.sample(range(len(descriptions)), 5)
random_descriptions = [descriptions[i] for i in random_indices]
random_recipe_names = [recipe_names[i] for i in random_indices]  # Получим случайные названия рецептов

# Инициализируем TfidfVectorizer
vectorizer = TfidfVectorizer()

# Преобразуем тексты в числовые векторы
tfidf_matrix = vectorizer.fit_transform(random_descriptions)

# Преобразуем результат в DataFrame для удобства
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=vectorizer.get_feature_names_out(), index=random_recipe_names)

# Вычисляем косинусное расстояние между каждой парой рецептов
distances = pd.DataFrame(index=random_recipe_names, columns=random_recipe_names)

for i in range(len(random_recipe_names)):
    for j in range(len(random_recipe_names)):
        if i == j:
            distances.iloc[i, j] = 0.0
        else:
            distances.iloc[i, j] = cosine(tfidf_matrix.toarray()[i], tfidf_matrix.toarray()[j])

# Преобразуем тип данных в float
distances = distances.astype(float)

# Выведем результат
distances
# Out:
#                                                    campfire  or oven  pepper jack and bacon potatoes  \
# campfire  or oven  pepper jack and bacon potatoes                                           0.000000
# jamie deen s chicken salad                                                                  0.807058
# rainbow risotto                                                                             0.914321
# whipped topping dollops on spoons                                                           0.827754
# shrimp marinara                                                                             0.948036
#
#                                                    jamie deen s chicken salad  \
# campfire  or oven  pepper jack and bacon potatoes                    0.807058
# jamie deen s chicken salad                                           0.000000
# rainbow risotto                                                      0.966846
# whipped topping dollops on spoons                                    0.922309
# shrimp marinara                                                      0.892112
#
#                                                    rainbow risotto  \
# campfire  or oven  pepper jack and bacon potatoes         0.914321
# jamie deen s chicken salad                                0.966846
# rainbow risotto                                           0.000000
# whipped topping dollops on spoons                         0.935732
# shrimp marinara                                           0.967262
#
#                                                    whipped topping dollops on spoons  \
# campfire  or oven  pepper jack and bacon potatoes                           0.827754
# jamie deen s chicken salad                                                  0.922309
# rainbow risotto                                                             0.935732
# whipped topping dollops on spoons                                           0.000000
# shrimp marinara                                                             0.905227
#
#                                                    shrimp marinara
# campfire  or oven  pepper jack and bacon potatoes         0.948036
# jamie deen s chicken salad                                0.892112
# rainbow risotto                                           0.967262
# whipped topping dollops on spoons                         0.905227
# shrimp marinara                                           0.000000

# %% [markdown]
# 3.3 Какие рецепты являются наиболее похожими? Прокомментируйте результат (словами).

# %% [markdown]
# Чтобы определить, какие рецепты являются наиболее похожими, нужно проанализировать значения косинусного расстояния в таблице. Чем ближе значение косинусного расстояния к 0, тем более похожи рецепты
